# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
# !pip install stable-baselines3[extra]

# %%
import os

# %%
# !echo $DISPLAY

# %%
import pyvirtualdisplay


_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
_ = _display.start()

# %%
# !echo $DISPLAY
# Out:
# :0

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load Environment

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:36.0
# Episode:2 Score:15.0
# Episode:3 Score:11.0
# Episode:4 Score:23.0
# Episode:5 Score:41.0

# %% [markdown]
# # Understanding The Environment
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 1

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([ 3.6860552e+00,  2.3555627e+38,  2.8559607e-01, -1.5099735e+38],
#       dtype=float32)

# %% [markdown]
# # 3. Train an RL Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1434 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008882821 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00406    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.32        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 57.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011390225 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0853      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 37.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 4           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009915471 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 58.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 5            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0074980888 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.313        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 66.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 6           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005672595 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 64.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 7           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005036104 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 61          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 8            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0035256583 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.82         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 31.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 9            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0024835947 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 18.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 10           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0028317424 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.63         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00445     |
# |    value_loss           | 16           |
# ------------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved_Models', 'PPO_model')

# %%
model.save(PPO_path)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'Training/Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %%
model = PPO.load('PPO_model', env=env)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_289/1352074225.py in <module>
# ----> 1 model = PPO.load('PPO_model', env=env)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/base_class.py in load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     686
#     687         data, params, pytorch_variables = load_from_zip_file(
# --> 688             path, device=device, custom_objects=custom_objects, print_system_info=print_system_info
#     689         )
#     690
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/save_util.py in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     386         and dict of pytorch variables
#     387     """
# --> 388     load_path = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     389
#     390     # set device to cpu if cuda is not available
#
# /srv/conda/envs/notebook/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/save_util.py in open_path_str(path, mode, verbose, suffix)
#     230     :return:
#     231     """
# --> 232     return open_path(pathlib.Path(path), mode, verbose, suffix)
#     233
#     234
#
# /srv/conda/envs/notebook/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/save_util.py in open_path_pathlib(path, mode, verbose, suffix)
#     282     # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
#     283
# --> 284     return open_path(path, mode, verbose, suffix)
#     285
#     286
#
# /srv/conda/envs/notebook/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/save_util.py in open_path_pathlib(path, mode, verbose, suffix)
#     262                 path, suffix = newpath, None
#     263             else:
# --> 264                 raise error
#     265     else:
#     266         try:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/stable_baselines3/common/save_util.py in open_path_pathlib(path, mode, verbose, suffix)
#     254     if mode == "r":
#     255         try:
# --> 256             path = path.open("rb")
#     257         except FileNotFoundError as error:
#     258             if suffix is not None and suffix != "":
#
# /srv/conda/envs/notebook/lib/python3.7/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1206             self._raise_closed()
#    1207         return io.open(self, mode, buffering, encoding, errors, newline,
# -> 1208                        opener=self._opener)
#    1209
#    1210     def read_bytes(self):
#
# /srv/conda/envs/notebook/lib/python3.7/pathlib.py in _opener(self, name, flags, mode)
#    1061     def _opener(self, name, flags, mode=0o666):
#    1062         # A stub for the opener argument to built-in open()
# -> 1063         return self._accessor.open(self, flags, mode)
#    1064
#    1065     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PPO_model.zip'

# %% [markdown]
# # 4. Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()

# %% [markdown]
# # 5. Test Model

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break

# %%
env.close()

# %% [markdown]
# # 6. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
# !tensorboard --logdir={training_log_path}

# %% [markdown]
# # 7. Adding a callback to the training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()

# %% [markdown]
# # 8. Changing Policies

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %% [markdown]
# # 9. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()
